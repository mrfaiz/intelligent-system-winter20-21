# %% [markdown]
# ## Feature Selection Assigment
#
#
# ---
#
# By
#   - Rakibuzzaman Mahmud
#   - Mithun Das
#   - Muhtasim Fuad Ansari

# %%
import pandas as pd
from mpl_toolkits import mplot3d
from sklearn.decomposition import PCA
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt

# %%
df_combined = pd.read_csv('combined_data_updated.csv',parse_dates=['time'],index_col='time',)

df_combined.tail(10)
# Out:
#                      temp_c_station-a status_station-a  rain_mm_station-a  \
# time
# 2017-12-31 14:00:00          0.027800              max           0.067024
# 2017-12-31 15:00:00          0.062829              max           0.119611
# 2017-12-31 16:00:00          0.027800        increased           0.161681
# 2017-12-31 17:00:00         -0.217401              max           0.161681
# 2017-12-31 18:00:00         -0.287458              max           0.035472
# 2017-12-31 19:00:00         -0.322487              max           0.014437
# 2017-12-31 20:00:00         -0.322487              max           0.003920
# 2017-12-31 21:00:00         -0.322487              max           0.003920
# 2017-12-31 22:00:00         -0.357516              max           0.024954
# 2017-12-31 23:00:00         -0.410059              max           0.067024
#
#                      temp_c_station-b status_station-b  rain_mm_station-b  \
# time
# 2017-12-31 14:00:00         -0.269885           normal           0.025607
# 2017-12-31 15:00:00         -0.564148           normal           0.025607
# 2017-12-31 16:00:00         -0.790504        increased           0.025607
# 2017-12-31 17:00:00         -0.824458              max           0.025607
# 2017-12-31 18:00:00         -0.869729              max           0.025607
# 2017-12-31 19:00:00         -0.869729              max           0.025607
# 2017-12-31 20:00:00         -1.062132              max           0.025607
# 2017-12-31 21:00:00         -0.915000        increased           0.025607
# 2017-12-31 22:00:00         -0.994225        increased           0.025607
# 2017-12-31 23:00:00         -0.982907        increased           0.025607
#
#                      temp_c_station-c status_station-c  rain_mm_station-c  \
# time
# 2017-12-31 14:00:00         -0.102718              max           0.052326
# 2017-12-31 15:00:00         -0.114173              max           0.061417
# 2017-12-31 16:00:00         -0.205811        increased           0.106873
# 2017-12-31 17:00:00         -0.297449        increased           0.088691
# 2017-12-31 18:00:00         -0.343268              max           0.043235
# 2017-12-31 19:00:00         -0.343268              max           0.031113
# 2017-12-31 20:00:00         -0.308904        increased           0.031113
# 2017-12-31 21:00:00         -0.320359              max           0.031113
# 2017-12-31 22:00:00         -0.354723        increased           0.046265
# 2017-12-31 23:00:00         -0.423452              max           0.079600
#
#                      level_cm  flow_m2_s
# time
# 2017-12-31 14:00:00  3.516141   3.188807
# 2017-12-31 15:00:00  3.572971   3.231205
# 2017-12-31 16:00:00  3.686633   3.358398
# 2017-12-31 17:00:00  3.800295   3.443194
# 2017-12-31 18:00:00  3.970787   3.612785
# 2017-12-31 19:00:00  4.198110   3.782377
# 2017-12-31 20:00:00  4.425433   3.994366
# 2017-12-31 21:00:00  4.652756   4.206355
# 2017-12-31 22:00:00  4.936910   4.460742
# 2017-12-31 23:00:00  5.164234   4.672731

# %%
# Selecting value from 2015 to get the data where every station has their own data.


df_combined = df_combined[(df_combined.index.year >= 2014) & (df_combined.index.year <= 2017)]

df_combined.sample(10)
# Out:
#                      temp_c_station-a  status_station-a  ...  level_cm  flow_m2_s
# time                                                     ...
# 2015-05-10 01:00:00         -0.357516                 3  ... -1.143984  -0.834746
# 2016-01-21 09:00:00         -2.914614                 4  ... -0.291522  -0.024948
# 2017-02-26 14:00:00         -0.567688                 4  ...  2.493186   2.340851
# 2014-03-26 22:00:00         -1.145662                 3  ... -1.143984  -0.919542
# 2015-09-21 00:00:00         -0.567688                 4  ... -0.007368  -1.271444
# 2014-12-24 03:00:00         -0.304973                 3  ...  9.767527  12.813112
# 2014-04-19 07:00:00         -0.480116                 3  ... -1.314476  -1.207847
# 2014-05-17 10:00:00          1.008605                 1  ... -1.314476  -1.199367
# 2016-11-15 13:00:00         -0.550174                 4  ... -1.882784  -1.623345
# 2017-11-08 00:00:00         -1.338320                 4  ...  0.504109   0.382071
#
# [10 rows x 11 columns]

# %% [markdown]
# Since We have to predict the main station values then we can separate the 2 values in 2 variables.

# %%
df_combined.shape
# Out:
# (35064, 11)

# %%
# level_cm_and_flow_m2_s = df_combined.iloc[:, [9,10]]


level_cm = df_combined.iloc[:,0:-2]
flow_m2_s = df_combined.iloc[:,10]

# level_cm
flow_m2_s

# level_cm.shape
# Out:
# time
# 2014-01-01 00:00:00    0.089526
# 2014-01-01 01:00:00    0.089526
# 2014-01-01 02:00:00    0.089526
# 2014-01-01 03:00:00    0.089526
# 2014-01-01 04:00:00    0.089526
#                          ...
# 2017-12-31 19:00:00    3.782377
# 2017-12-31 20:00:00    3.994366
# 2017-12-31 21:00:00    4.206355
# 2017-12-31 22:00:00    4.460742
# 2017-12-31 23:00:00    4.672731
# Name: flow_m2_s, Length: 35064, dtype: float64

# %%
feature_df = df_combined.iloc[:, 0:-2]

# feature_df.columns
print(feature_df.shape)
feature_df.sample(10)
# Out:
# (157567, 9)
#                      temp_c_station-a status_station-a  rain_mm_station-a  \
# time
# 2013-04-07 07:00:00         -1.636065              max            0.00392
# 2000-09-28 03:00:00          0.360573        increased            0.00392
# 2014-09-07 12:00:00          1.604094           normal            0.00392
# 2011-10-20 05:00:00         -1.093119              max            0.00392
# 2004-07-18 06:00:00          0.360573        increased            0.00392
# 2016-07-29 21:00:00          1.043634              max            0.00392
# 2009-08-27 11:00:00          2.637441              low            0.00392
# 2004-09-30 05:00:00          0.360573        increased            0.00392
# 2005-06-30 16:00:00          0.360573        increased            0.00392
# 2016-01-18 12:00:00         -2.284096        increased            0.00392
#
#                      temp_c_station-b status_station-b  rain_mm_station-b  \
# time
# 2013-04-07 07:00:00         -0.835775              max           0.025607
# 2000-09-28 03:00:00          0.273370        increased           0.025607
# 2014-09-07 12:00:00          1.869182        decreased           0.025607
# 2011-10-20 05:00:00         -0.564148              max           0.025607
# 2004-07-18 06:00:00          0.884532        increased           0.025607
# 2016-07-29 21:00:00          1.156159        increased           0.025607
# 2009-08-27 11:00:00          1.971042        decreased           0.025607
# 2004-09-30 05:00:00          0.318641        increased           0.025607
# 2005-06-30 16:00:00          1.495694        decreased           0.025607
# 2016-01-18 12:00:00         -2.295773           normal           0.025607
#
#                      temp_c_station-c status_station-c  rain_mm_station-c
# time
# 2013-04-07 07:00:00         -1.145103              max           0.031113
# 2000-09-28 03:00:00          1.203128        increased           0.031113
# 2014-09-07 12:00:00          0.893849           normal           0.031113
# 2011-10-20 05:00:00         -0.824369        increased           0.031113
# 2004-07-18 06:00:00          0.641843        increased           0.031113
# 2016-07-29 21:00:00          0.584569        increased           0.031113
# 2009-08-27 11:00:00          1.558226        decreased           0.031113
# 2004-09-30 05:00:00         -0.950372              max           0.031113
# 2005-06-30 16:00:00          0.905303        decreased           0.031113
# 2016-01-18 12:00:00         -1.523111           normal           0.031113

# %% [markdown]
# ## Applying the PCA on the data.

# %%
# plt.style.use('ggplot')

# %% [markdown]
# ### PCA with All the components to figure out the highest values.

# %%
pca = PCA(n_components=None)
pc = pca.fit_transform(feature_df)
pc
# Out:
# array([[-4.83659113e-01,  2.78865595e+00, -8.73399897e-01, ...,
#          1.90182649e-03, -6.59611586e-03,  1.04067671e-03],
#        [-5.23835650e-01,  2.81894872e+00, -8.80233288e-01, ...,
#          7.16888435e-03, -6.51006279e-03,  4.26365277e-04],
#        [ 3.35935547e-01,  3.03217839e+00,  9.54339684e-01, ...,
#          3.62016339e-03,  4.19997420e-04, -2.16783374e-04],
#        ...,
#        [-1.89147447e+00, -1.25332804e+00,  3.44196285e-01, ...,
#         -2.37966019e-02, -5.90585020e-03, -2.13868911e-03],
#        [-1.56587327e+00, -6.68331787e-01,  8.97893095e-02, ...,
#          3.56253324e-03, -6.64774154e-03,  9.70761414e-03],
#        [-1.99947859e+00, -1.15901831e+00,  3.71391169e-01, ...,
#          5.15027454e-02, -6.75275777e-03,  3.27239481e-02]])

# %%
# pca.explained_variance_ratio_ * 100
pca.explained_variance_ratio_
# Out:
# array([5.21654985e-01, 2.39546489e-01, 1.64760676e-01, 4.58579241e-02,
#        2.70015983e-02, 7.32952024e-04, 3.39115486e-04, 8.48535972e-05,
#        2.14062315e-05])

# %%
df = pd.DataFrame({'variance':pca.explained_variance_ratio_,'PC':['PC-1','PC-2','PC-3','PC-4','PC-5','PC-6','PC-7','PC-8','PC-9']})

sb.barplot(x='PC',y='variance',data=df, color='c')

# %%
print("varience explained by 9 principal component = ", np.cumsum(sum(pca.explained_variance_ratio_)*100))
# Out:
# varience explained by 9 principal component =  [100.]

# %%
pca.explained_variance_ratio_ * 100
# Out:
# array([5.21654985e+01, 2.39546489e+01, 1.64760676e+01, 4.58579241e+00,
#        2.70015983e+00, 7.32952024e-02, 3.39115486e-02, 8.48535972e-03,
#        2.14062315e-03])

# %% [markdown]
# ### Applying PCA with the first 3 Highest value.

# %%
pca = PCA(n_components=3)
pc = pca.fit_transform(feature_df)


pca.explained_variance_ratio_
# Out:
# array([0.52165499, 0.23954649, 0.16476068])

# %%
newComponents = pd.DataFrame(data = pc,columns= ['PC-1','PC-2','PC-3'])

newComponents
# Out:
#            PC-1      PC-2      PC-3
# 0     -0.483659  2.788656 -0.873400
# 1     -0.523836  2.818949 -0.880233
# 2      0.335936  3.032178  0.954340
# 3      0.322376  3.049963  0.977805
# 4      0.302442  3.064295  0.971895
# ...         ...       ...       ...
# 35059 -2.240596 -1.422644 -0.564749
# 35060 -1.919499 -0.837928 -0.833578
# 35061 -1.891474 -1.253328  0.344196
# 35062 -1.565873 -0.668332  0.089789
# 35063 -1.999479 -1.159018  0.371391
#
# [35064 rows x 3 columns]

# %%
# plt.plot(np.cumsum(pca.explained_variance_ratio_))
# plt.xlabel('number of component')
# plt.ylabel('Explained variance')

# %%
df = pd.DataFrame({'variance':pca.explained_variance_ratio_,'PC':['PC-1','PC-2','PC-3']})

sb.barplot(x='PC',y='variance',data=df, color='c')

# %%
print("PC-1 Value = ",int(np.cumsum(pca.explained_variance_ratio_*100)[0]),'%')
print("PC-2 Value = ",int(np.cumsum(pca.explained_variance_ratio_*100)[1]),'%')
print("PC-3 Value = ",int(np.cumsum(pca.explained_variance_ratio_*100)[2]),'%')
# print("PC-4 Value = ",int(np.cumsum(pca.explained_variance_ratio_*100)[3]),'%')
# print("PC-5 Value = ",int(np.cumsum(pca.explained_variance_ratio_*100)[4]),'%')
# Out:
# PC-1 Value =  52 %
# PC-2 Value =  76 %
# PC-3 Value =  92 %

# %%
pca = PCA(n_components=.9)
pc = pca.fit_transform(feature_df)
pc
# Out:
# array([[-0.48365911,  2.78865595, -0.8733999 ],
#        [-0.52383565,  2.81894872, -0.88023329],
#        [ 0.33593555,  3.03217839,  0.95433968],
#        ...,
#        [-1.89147447, -1.25332804,  0.34419628],
#        [-1.56587327, -0.66833179,  0.08978931],
#        [-1.99947859, -1.15901831,  0.37139117]])

# %%
plt.figure(figsize=(10,7))
sb.scatterplot(pc[:, 0],pc[:, 1],s=40,
                hue= df_combined.level_cm)

plt.title("2D Scatterplot:", pad = 20)
plt.xlabel("PC1")
plt.ylabel("PC2")
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0, 0.5, 'PC2')

# %%
fig = plt.figure(figsize=(10,7))
ax = plt.axes(projection='3d')

sctt = ax.scatter3D(pc[:, 0],pc[:, 1],pc[:,2],s=40,
                c= df_combined.level_cm , alpha = 0.9)
plt.title("3D Ploting: ")
ax.set_xlabel('Pricipal component 1')
ax.set_ylabel('PC2')
ax.set_zlabel('PC3')
# Out:
# Text(0.5, 0, 'PC3')

# %% [markdown]
# From the variance ratio we see that the first 5 principle components can explain the 95% information about the feature space and by doing so we are reducing the data by 45%. We are taking 5 features from 9 available ones.

# %%
pca.components_

# %%
# components = pd.DataFrame(pca.components_,columns=feature_df.columns,index = ['PC-1','PC-2','PC-3','PC-4','PC-5'])
# components

# %%
newComponents.to_csv("pca_data.csv")
