# %% [markdown]
# # Intelligent Systems
# # Exercise 2 / Design
# ### Working Group: Intelligent Systems
# ### Lecture: Prof. Dr.-Ing. habil.  Sven Tomforde
# ### Exercise: Ma. Sc. Simon Reichhuber (mail to: [Simon.Reichhuber@informatik.uni-kiel.de](mailto:Simon.Reichhuber@informatik.uni-kiel.de))

# %% [markdown]
# ## Exercise 2 - Python Visualization: WSA LÜBECK

# %% [markdown]
# ## A. Download historical water level data for the period of October 2020 (20th of October until 10th of November inclusively)
# https://www.pegelonline.wsv.de/webservices/files/Wasserstand+Rohdaten/OSTSEE/LT+KIEL.
# (Hint the tool wget might help)

# %%
url = 'https://www.pegelonline.wsv.de/webservices/files/Wasserstand+Rohdaten/OSTSEE/LT+KIEL'
directory = ''

# %% [markdown]
# ### B. Load the data into a single pandas dataframe

# %%
# Merge days to a single dataframe
# Out:
#        WSA LÜBECK  OSTSEE  LT KIEL  9610050  W_O  cm  XXX,XXX  XX.XX.XXXX  \
# 00:01         485     NaN      NaN      NaN  NaN NaN      NaN         NaN
# 00:02         485     NaN      NaN      NaN  NaN NaN      NaN         NaN
# 00:03         485     NaN      NaN      NaN  NaN NaN      NaN         NaN
# 00:04         485     NaN      NaN      NaN  NaN NaN      NaN         NaN
# 00:05         485     NaN      NaN      NaN  NaN NaN      NaN         NaN
# ...           ...     ...      ...      ...  ...  ..      ...         ...
# 23:56         456     NaN      NaN      NaN  NaN NaN      NaN         NaN
# 23:57         456     NaN      NaN      NaN  NaN NaN      NaN         NaN
# 23:58         456     NaN      NaN      NaN  NaN NaN      NaN         NaN
# 23:59         456     NaN      NaN      NaN  NaN NaN      NaN         NaN
# 24:00         455     NaN      NaN      NaN  NaN NaN      NaN         NaN
#
#        XX:XX  PNP  -4,987
# 00:01    NaN  NaN     NaN
# 00:02    NaN  NaN     NaN
# 00:03    NaN  NaN     NaN
# 00:04    NaN  NaN     NaN
# 00:05    NaN  NaN     NaN
# ...      ...  ...     ...
# 23:56    NaN  NaN     NaN
# 23:57    NaN  NaN     NaN
# 23:58    NaN  NaN     NaN
# 23:59    NaN  NaN     NaN
# 24:00    NaN  NaN     NaN
#
# [24480 rows x 11 columns]

# %% [markdown]
# ### C. Visualize the dataframe via matplotlib

# %%
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### D. Approximate the water levels with the usage of numpy.polyfit

# %%
import numpy.polynomial.polynomial as polyNew
from matplotlib import pyplot as plt
